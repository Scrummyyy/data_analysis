# %% [markdown]
# <a href="https://colab.research.google.com/github/Scrummyyy/python_projects/blob/main/Pandas_practise_sns_count_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/sample_data/train.csv')

# %% [markdown]
# #1 Show shape

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# #2 All information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #3 Get overall statistics

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %% [markdown]
# #4 Filter the data

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df[df['Sex'] == 'male'].head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
sum(df['Survived'] == 1)
# Out:
# 342

# %% [markdown]
# #5 Check for null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
per_null = round(df.isnull().sum() * 100/len(df),2)
per_null
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %% [markdown]
# #6 Drop null column Cabin

# %%
df.drop('Cabin', axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# #7 Handle missing values

# %%
# The most popular value
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].fillna('S').head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# /tmp/ipython-input-58-2940318962.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace = True)

# %%
df[df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %% [markdown]
# #7 Category encoding

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Gender'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked  Gender
# 0      0  A/5 21171  7.25        S       0

# %%
x = df['Gender'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df.insert(5, 'Genser_New', x)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Genser_New  \
# 0            1         0       3  Braund, Mr. Owen Harris  male           0
#
#     Age  SibSp  Parch     Ticket  Fare Embarked  Gender
# 0  22.0      1      0  A/5 21171  7.25        S       0

# %%
df = df.rename(columns = {'Genser_New': 'Gender_New'})
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender_New  \
# 0            1         0       3  Braund, Mr. Owen Harris  male           0
#
#     Age  SibSp  Parch     Ticket  Fare Embarked  Gender
# 0  22.0      1      0  A/5 21171  7.25        S       0

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
#Encoding with pandas method
pd.get_dummies(df, columns = ['Embarked']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Gender_New  \
# 0                            Braund, Mr. Owen Harris    male           0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           1
# 2                             Heikkinen, Miss. Laina  female           1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           1
# 4                           Allen, Mr. William Henry    male           0
#
#     Age  SibSp  Parch            Ticket     Fare  Gender  Embarked_C  \
# 0  22.0      1      0         A/5 21171   7.2500       0       False
# 1  38.0      1      0          PC 17599  71.2833       1        True
# 2  26.0      0      0  STON/O2. 3101282   7.9250       1       False
# ...

# %% [markdown]
# #8 Univariate analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %% [markdown]
# Survival statistic

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(df, x ='Survived', hue="Survived")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# Category for classes

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(df, x = 'Pclass', hue="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Number of male and female passengers

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(df, x = 'Sex', hue = 'Pclass', stat = 'percent')
# Out:
# <Axes: xlabel='Sex', ylabel='percent'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df, y = 'Age')
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# #9 Bivariate analysis

# %% [markdown]
# Who had better chance to survive?

# %%
sns.barplot(x = 'Sex', y = 'Survived', data = df, hue = 'Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# Which Pclass had better chance to survive?

# %%
sns.barplot(x = 'Pclass', y = 'Survived', data = df, hue = 'Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# #10 Feature Engineering

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender_New', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
df['Family_size'] = df['SibSp'] + df['Parch']

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender_New  \
# 0            1         0       3  Braund, Mr. Owen Harris  male           0
#
#     Age  SibSp  Parch     Ticket  Fare Embarked  Gender  Family_size
# 0  22.0      1      0  A/5 21171  7.25        S       0            1

# %%
df['Fare_per_person'] = df['Fare'] / df['Family_size'] + 1

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender_New  \
# 0            1         0       3  Braund, Mr. Owen Harris  male           0
#
#     Age  SibSp  Parch     Ticket  Fare Embarked  Gender  Family_size  \
# 0  22.0      1      0  A/5 21171  7.25        S       0            1
#
#    Fare_per_person
# 0             8.25
